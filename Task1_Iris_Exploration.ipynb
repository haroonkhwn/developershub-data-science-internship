# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

print("All libraries working")
# Out:
# All libraries working

# %%
# Task 1: Exploring and Visualizing Iris Dataset

# Objective:
# To understand the structure of the Iris dataset and perform
# basic data exploration and visualization using Python libraries.

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
import matplotlib.pyplot as plt

sns.scatterplot(
    x="sepal_length",
    y="sepal_width",
    hue="species",
    data=df
)

plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
df["petal_length"].hist()
plt.title("Petal Length Distribution")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(x="species", y="petal_width", data=df)
plt.title("Petal Width by Species")
plt.show()

# %%
# Conclusion:
# The Iris dataset shows clear differences between flower species.
# Visualizations help in understanding relationships, distributions,
# and detecting outliers in the dataset.
